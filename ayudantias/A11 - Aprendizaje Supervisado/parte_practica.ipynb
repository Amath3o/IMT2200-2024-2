# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Llego el momento de practicar
#
# Vamos a utilizar el siguiente datasets de información de autos.
#
# Lo que haremos será intentar predecir el precio ($Y$ o variable dependiente), en función de las variables independientes que serán las otras columnas.

# %%
cars = pd.read_csv('data/car.csv')
cars
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
cars.dropna(inplace=True)

# %% [markdown]
# #### Como podrás observar muchas de las columnas son de tipo object. Una práctica muy buena sería utilizar algunas de estas como variables dummie, sin embargo para esta ocasión solo utilizaremos las siguientes como variables independientes:
#
# **'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize','boreratio', 'horsepower', 'citympg', 'highwaympg'**

# %%
x_cols =['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize','boreratio', 'horsepower', 'citympg', 'highwaympg']
X = cars[x_cols]
y = cars['price']
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   wheelbase   205 non-null    float64
#  1   carlength   205 non-null    float64
#  2   carwidth    205 non-null    float64
#  3   curbweight  205 non-null    int64
#  4   enginesize  205 non-null    int64
#  5   boreratio   205 non-null    float64
#  6   horsepower  205 non-null    int64
#  7   citympg     205 non-null    int64
#  8   highwaympg  205 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 14.5 KB

# %%
X
# Out:
#      wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0         88.6      168.8      64.1        2548         130       3.47
# 1         88.6      168.8      64.1        2548         130       3.47
# 2         94.5      171.2      65.5        2823         152       2.68
# 3         99.8      176.6      66.2        2337         109       3.19
# 4         99.4      176.6      66.4        2824         136       3.19
# ..         ...        ...       ...         ...         ...        ...
# 200      109.1      188.8      68.9        2952         141       3.78
# 201      109.1      188.8      68.8        3049         141       3.78
# 202      109.1      188.8      68.9        3012         173       3.58
# 203      109.1      188.8      68.9        3217         145       3.01
# 204      109.1      188.8      68.9        3062         141       3.78
#
#      horsepower  citympg  highwaympg
# 0           111       21          27
# 1           111       21          27
# ...

# %% [markdown]
# #### Ahora llegó el momento de que hagas tu parte, lo que harás será entregar un modelo de regresión lineal.

# %% [markdown]
# ### Paso 1: Splitear los datos en conjunto de test y entrenamiento. Para ello vas a utilizar un tamaño de test equivalente al 30% de la muestra con un random state de 42.

# %%
#Escribir aquí la librería que se necesita para dividir el dataset en entrenamiento y prueba

# %% [markdown]
# ### Paso 2: Entrenar el modelo (Método fit)

# %%
#Escribir aquí la librería que se necesita para escalar los datos

# %%
# Out:
# LinearRegression()

# %% [markdown]
# ### Paso 3: Realizar las predicciones con el modelo.

# %% [markdown]
# ### Paso 4: Evaluarlo usando las métricas vistas en clases/ayudantías.

# %%
#Escribir aquí la librería que se necesita para calcular el error cuadrático medio y otras métricas

# %%
# Out:
# RMSE: 4035.2358199829396
# MAE: 2810.37908894599
# R2: 0.7649812490311778

# %% [markdown]
# ### Algo que nos debe alarmar es que el $R^2$ no nos da un valor cercano a 1, así como los otros valores son muy grandes. ¿Qué pasará si normalizamos los datos? (Spoiler: Esto lo hacemos para eliminar el ruido de los datos)

# %%
#escribir aqui la librería que se necesita para estandarizar los datos  (StandardScaler)

# %%
#Queda esta parte de codigo para que te hagas una idea del output
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=x_cols)
X_train_scaled_df
# Out:
#      wheelbase  carlength  carwidth  curbweight  enginesize  boreratio  \
# 0     0.573309   0.076413  0.235105   -0.221382   -0.121429  -0.038909
# 1     0.622875   0.302880  0.924984    0.646950    0.314497   1.692945
# 2     0.573309   0.076413  0.235105   -0.179118   -0.412047  -0.186301
# 3    -2.037199  -2.430901 -0.960684   -1.448956   -0.847973  -1.512828
# 4     0.375042   0.173470 -0.546757    0.262732    0.895732  -0.038909
# ..         ...        ...       ...         ...         ...        ...
# 138   0.044598   0.310968  0.878992    1.086878    1.307440   0.403266
# 139   0.755053   1.160219  0.419073    0.925507    0.895732  -0.038909
# 140  -0.731945  -0.756662 -1.006675   -1.220347   -0.726882  -0.628477
# 141   0.655920   0.715373  0.787008    0.850585    1.065259  -0.186301
# 142   0.242865   0.804343  0.235105    1.388489    1.307440   0.403266
#
#      horsepower   citympg  highwaympg
# 0     -0.340756  0.370118    0.270248
# ...

# %%
# Out:
# RMSE: 4028.4183072197743
# MAE: 2803.6921397793103
# R2: 0.7657747044396241

# %% [markdown]
# ### Evaluando el rendimiento de la regresión obtenemos lo siguiente:

# %%
# Out:
# 0.7657747044396241
# 0.84252489773979

# %% [markdown]
# ### Se ajusta relativamente bien en el set de entrenamiento pero no en el de prueba. ¿A qué tipo de problema nos estamos enfrentando?
#
# Prueba modificando el tamaño del test a 0.2 y el escalado a Normalizer y ve que sucede con el rendimiento.
