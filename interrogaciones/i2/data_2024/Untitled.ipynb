# %%
import pandas as pd

# %%
df1 = pd.read_csv("AtencionesUrgenciaMaule2023.csv")
df1
# Out:
#        IdEstablecimiento                    NEstablecimiento  IdCausa  \
# 0                 16-107            Hospital de Constitución       40
# 1                 16-954                        SUR Mercedes       18
# 2                 16-831                   SAPU Carlos Trupp       35
# 3                 16-813                SAR Luis Tobar Rojas       40
# 4                 16-954                        SUR Mercedes       35
# ...                  ...                                 ...      ...
# 859835            201043            SUR La Huerta de Hualañé       34
# 859836            16-107            Hospital de Constitución       34
# 859837            16-813                SAR Luis Tobar Rojas       34
# 859838            16-952                 SUR Sagrada Familia       14
# 859839            16-100  Hospital San Juan de Dios (Curicó)       30
#
#                                                GlosaCausa  Total  Menores_1  \
# ...

# %%
df2 = pd.read_csv("datos_230101_231231.csv", sep=";")
df2
# Out:
#      FECHA (YYMMDD)  HORA (HHMM)  Registros validados  Registros preliminares  \
# 0            230101            0                  7.0                     NaN
# 1            230102            0                  5.0                     NaN
# 2            230103            0                  6.0                     NaN
# 3            230104            0                  5.0                     NaN
# 4            230105            0                  4.0                     NaN
# ..              ...          ...                  ...                     ...
# 359          231226            0                  8.0                     NaN
# 360          231227            0                  8.0                     NaN
# 361          231228            0                  4.0                     NaN
# 362          231229            0                  5.0                     NaN
# 363          231230            0                  3.0                     NaN
#
# ...
